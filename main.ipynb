# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error,root_mean_squared_error,adjusted_rand_score
from sklearn.linear_model import Ridge,Lasso
from sklearn.datasets import load_diabetes

# %%
diabetis = load_diabetes()

# %%
diabetis

# %%
df  = pd.DataFrame(diabetis.data, columns=diabetis.feature_names)

# %%
df['target'] = diabetis.target

# %%
df
# Out:
#           age       sex       bmi  ...        s5        s6  target
# 0    0.038076  0.050680  0.061696  ...  0.019907 -0.017646   151.0
# 1   -0.001882 -0.044642 -0.051474  ... -0.068332 -0.092204    75.0
# 2    0.085299  0.050680  0.044451  ...  0.002861 -0.025930   141.0
# 3   -0.089063 -0.044642 -0.011595  ...  0.022688 -0.009362   206.0
# 4    0.005383 -0.044642 -0.036385  ... -0.031988 -0.046641   135.0
# ..        ...       ...       ...  ...       ...       ...     ...
# 437  0.041708  0.050680  0.019662  ...  0.031193  0.007207   178.0
# 438 -0.005515  0.050680 -0.015906  ... -0.018114  0.044485   104.0
# 439  0.041708  0.050680 -0.015906  ... -0.046883  0.015491   132.0
# 440 -0.045472 -0.044642  0.039062  ...  0.044529 -0.025930   220.0
# 441 -0.045472 -0.044642 -0.073030  ... -0.004222  0.003064    57.0
#
# [442 rows x 11 columns]

# %%
x = df.drop(columns=['target'])

# %%
x
# Out:
#           age       sex       bmi  ...        s4        s5        s6
# 0    0.038076  0.050680  0.061696  ... -0.002592  0.019907 -0.017646
# 1   -0.001882 -0.044642 -0.051474  ... -0.039493 -0.068332 -0.092204
# 2    0.085299  0.050680  0.044451  ... -0.002592  0.002861 -0.025930
# 3   -0.089063 -0.044642 -0.011595  ...  0.034309  0.022688 -0.009362
# 4    0.005383 -0.044642 -0.036385  ... -0.002592 -0.031988 -0.046641
# ..        ...       ...       ...  ...       ...       ...       ...
# 437  0.041708  0.050680  0.019662  ... -0.002592  0.031193  0.007207
# 438 -0.005515  0.050680 -0.015906  ...  0.034309 -0.018114  0.044485
# 439  0.041708  0.050680 -0.015906  ... -0.011080 -0.046883  0.015491
# 440 -0.045472 -0.044642  0.039062  ...  0.026560  0.044529 -0.025930
# 441 -0.045472 -0.044642 -0.073030  ... -0.039493 -0.004222  0.003064
#
# [442 rows x 10 columns]

# %%
y = df['target']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %%
scalar = StandardScaler()

# %%
x_train_scaled = scalar.fit_transform(x_train)

# %%
x_test_scaled = scalar.transform(x_test)

# %%
Ridge_model = Ridge()
Lasso_model  = Lasso()

# %%
Ridge_model.fit(x_train_scaled, y_train)
# Out:
# Ridge()

# %%
Lasso_model.fit(x_train_scaled, y_train)
# Out:
# Lasso()

# %%
Ridge_model.predict(x_test_scaled)
# Out:
# array([172.19853474, 244.87361461, 104.90709954,  75.67623597,
#        122.47576962, 176.37569869, 159.98040141, 164.81933296,
#        157.14707506, 190.58251407, 112.78222611, 213.82060371,
#        151.42858397, 180.18625564, 103.83512323, 111.63817206,
#        124.95327692,  91.03184961, 176.6822267 , 117.20579108,
#         92.63588853, 180.17273625, 187.00996948, 230.51016933,
#        168.27859964, 197.43988374,  84.97305308, 135.35222014,
#        118.75033694, 189.37227812, 265.41332768, 150.35194038,
#        141.36226434, 154.94202389, 143.63452726, 163.89837902,
#        143.20592205, 242.62720398, 105.1074853 ,  78.59246401,
#        265.33190457, 190.66515486, 185.00592476, 161.60233173,
#        191.55617685,  90.38560989, 101.53241248, 204.34517674,
#        114.31320503, 193.44669688, 121.24987869,  70.20332762,
#        221.76624183,  72.70877001, 140.21766069, 121.56376992,
#         87.87985768, 231.14926939, 187.03453576, 121.12401408,
# ...

# %%
Lasso_model.predict(x_test_scaled)
# Out:
# array([170.66098364, 243.67604283, 104.04495855,  75.27406962,
#        125.4592504 , 173.12012916, 160.96383562, 165.39959894,
#        157.86603783, 188.63373757, 105.4198045 , 214.20773994,
#        149.4378158 , 178.798812  , 106.69867628, 110.02493678,
#        123.86889964,  92.37058353, 175.32977236, 117.03885654,
#         94.68102726, 181.18177393, 186.68210164, 229.29845584,
#        166.56177361, 192.18039731,  88.0713221 , 137.1428071 ,
#        116.38604187, 187.71739618, 261.12134677, 153.80879403,
#        141.06978319, 157.45633425, 145.31876948, 162.68739012,
#        143.88407683, 241.06374945, 106.45099552,  79.18590295,
#        268.39297669, 185.52246084, 183.84237359, 163.87399595,
#        195.43970854,  93.65450135, 105.51664733, 203.22147242,
#        117.06635462, 193.87193788, 122.84272009,  73.29394894,
#        220.68000511,  74.81309266, 142.84444767, 123.84402922,
#         89.48007509, 228.48784334, 182.65708118, 120.25711554,
# ...

# %%
mean_squared_error(y_test, Ridge_model.predict(x_test_scaled))
# Out:
# 2825.320047862989

# %%
mean_squared_error(y_test, Lasso_model.predict(x_test_scaled))
# Out:
# 2870.839560035549

# %%
mean_absolute_error(y_test, Ridge_model.predict(x_test_scaled))
# Out:
# 42.899926926404916

# %%
mean_absolute_error(y_test, Lasso_model.predict(x_test_scaled))
# Out:
# 43.338511938445855

# %%
r2_score(y_test, Ridge_model.predict(x_test_scaled))
# Out:
# 0.5279162793355214

# %%
r2_score(y_test, Lasso_model.predict(x_test_scaled))
# Out:
# 0.5203104080341416

# %%
root_mean_squared_error(y_test, Ridge_model.predict(x_test_scaled))
# Out:
# 53.1537397354409

# %%
root_mean_squared_error(y_test, Lasso_model.predict(x_test_scaled))
# Out:
# 53.58021612531578
